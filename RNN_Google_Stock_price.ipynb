# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshiyadavnitsgr/Artificial-Neural-Network/blob/master/RNN_Google_Stock_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
train_data= pd.read_csv('/content/Google_Stock_Price_Train.csv')
test_data=pd.read_csv('/content/Google_Stock_Price_Test.csv')

# %%
train_data
# Out:
#             Date    Open    High     Low   Close      Volume
# 0       1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1       1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2       1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3       1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4       1/9/2012  322.04  322.29  309.46  620.76  11,688,800
# 5      1/10/2012  313.70  315.72  307.30  621.43   8,824,000
# 6      1/11/2012  310.59  313.52  309.40  624.25   4,817,800
# 7      1/12/2012  314.43  315.26  312.08  627.92   3,764,400
# 8      1/13/2012  311.96  312.30  309.37  623.28   4,631,800
# 9      1/17/2012  314.81  314.81  311.67  626.86   3,832,800
# 10     1/18/2012  312.14  315.82  309.90  631.18   5,544,000
# 11     1/19/2012  319.30  319.30  314.55  637.82  12,657,800
# 12     1/20/2012  294.16  294.40  289.76  584.39  21,231,800
# 13     1/23/2012  291.91  293.23  290.49  583.92   6,851,300
# ...

# %%
x_train=train_data.iloc[:, 1:2]

# %%
x_train
# Out:
#         Open
# 0     325.25
# 1     331.27
# 2     329.83
# 3     328.34
# 4     322.04
# 5     313.70
# 6     310.59
# 7     314.43
# 8     311.96
# 9     314.81
# 10    312.14
# 11    319.30
# 12    294.16
# 13    291.91
# 14    292.07
# 15    287.68
# 16    284.92
# 17    284.32
# 18    287.95
# 19    290.41
# 20    291.38
# 21    291.34
# 22    294.23
# 23    296.39
# 24    302.44
# 25    303.18
# 26    304.87
# 27    302.81
# 28    304.11
# 29    304.63
# ...      ...
# 1228  766.92
# 1229  771.37
# 1230  762.61
# 1231  772.63
# 1232  767.73
# 1233  764.26
# 1234  760.00
# 1235  771.53
# 1236  770.07
# 1237  757.44
# 1238  744.59
# 1239  757.71
# 1240  764.73
# 1241  761.00
# 1242  772.48
# 1243  780.00
# 1244  785.04
# 1245  793.90
# 1246  797.40
# 1247  797.34
# 1248  800.40
# 1249  790.22
# 1250  796.76
# 1251  795.84
# 1252  792.36
# 1253  790.90
# 1254  790.68
# 1255  793.70
# 1256  783.33
# 1257  782.75
#
# [1258 rows x 1 columns]

# %% [markdown]
# ### Data preprocessing

# %%
from sklearn.preprocessing import MinMaxScaler
mms= MinMaxScaler(feature_range=(0,1))
training_set_scaled=mms.fit_transform(x_train)

# %%
training_set_scaled
# Out:
# array([[0.08581368],
#        [0.09701243],
#        [0.09433366],
#        ...,
#        [0.95725128],
#        [0.93796041],
#        [0.93688146]])

# %% [markdown]
# ### Creating a data structure with 60 timetages and 1 output

# %%
x_train=[]
y_train=[]
for i in range(60,1258):
  x_train.append(training_set_scaled[i-60:i, 0])
  y_train.append(training_set_scaled[i,0])
x_train=np.array(x_train)
y_train=np.array(y_train)

# %%
x_train.shape
# Out:
# (1198, 60)

# %%
x_train=np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %% [markdown]
# #### The LSTM network expects the input data (X) to be provided with a specific array structure in the form of: [samples, time steps, features].

# %% [markdown]
# #### Buildig our LSTM layer

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
# Out:
# Using TensorFlow backend.

# %%
regressor= Sequential()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0902 01:51:57.199471 140264325519232 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
regressor.add(LSTM(units =50, return_sequences=True, input_shape= (x_train.shape[1], 1)))
regressor.add(Dropout(0.2))
# Out:
# W0902 01:51:57.254241 140264325519232 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0902 01:51:57.268326 140264325519232 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0902 01:51:57.545267 140264325519232 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# ...

# %%
regressor.add(LSTM(units =50, return_sequences=True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units =50, return_sequences=True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units =50))
regressor.add(Dropout(0.2))

# %%
regressor.add(Dense(units=1))

# %%
regressor.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# W0902 01:51:58.373602 140264325519232 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
regressor.fit(x=x_train, y=y_train, epochs=100, batch_size=10)
# Out:
# W0902 01:51:58.874557 140264325519232 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0902 01:52:01.609832 140264325519232 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 1/100
# 1198/1198 [==============================] - 58s 48ms/step - loss: 0.0207
# Epoch 2/100
# 1198/1198 [==============================] - 51s 42ms/step - loss: 0.0058
# Epoch 3/100
# 1198/1198 [==============================] - 51s 42ms/step - loss: 0.0053
# Epoch 4/100
# 1198/1198 [==============================] - 51s 42ms/step - loss: 0.0048
# Epoch 5/100
# ...

# %%
real_stock_price=test_data.iloc[:, 1:2].values

# %%
dataset_total=pd.concat((train_data['Open'], test_data['Open']), axis=0)
inputs=dataset_total[len(dataset_total)-len(test_data)-60:].values
inputs=inputs.reshape(-1,1)
inputs=mms.transform(inputs)

x_test=[]
for i in range(60, 80):
  x_test.append(inputs[i-60:i, 0])

x_test=np.array(x_test)
x_test=np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

predicted_stock_price=regressor.predict(x_test)
predicted_stock_price=mms.inverse_transform(predicted_stock_price)

# %% [markdown]
# #### Visulaisation

# %%
plt.plot(real_stock_price, color='red', label='Real stock price')
plt.plot(predicted_stock_price, color='blue', label='Predicted stock price')
plt.title('Stock price prediction')
plt.xlabel('Date')
plt.ylabel('Stock price')
plt.legend()
plt.show()

# %%
import math
from sklearn.metrics import mean_squared_error
rmse = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))

# %%
print(rmse)
# Out:
# 25.74979627361424
